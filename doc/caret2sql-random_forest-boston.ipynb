# %%
library(caret, quiet = TRUE)
library(base64enc)
library(httr, quiet = TRUE)

library(mlbench)
# Out:
# Attaching package: ‘httr’
#
# The following object is masked from ‘package:caret’:
#
#     progress

# %% [markdown]
# # Build a Model

# %%
## multiclass classification in iris dataset:

data(BostonHousing)
BostonHousing$chas = as.numeric(BostonHousing$chas)

set.seed(1960)

dataset = BostonHousing[, -14] 

create_model  =  function() {

    model <- train(medv ~ ., data = BostonHousing, method = "rf", maxnodes=6)    

    return(model)
}

# %%
model = create_model()
# cat(model$feature_names)
# print(model)

# %%
pred_labels <- predict(model, BostonHousing[, -14] , type="raw")
df = data.frame(BostonHousing[,14])
names(df) = c("medv")
df$Estimator = pred_labels
df$Error = df$Estimator - df$medv
MAPE = mean(abs(df$Error / df$medv))
summary(df)
MAPE
# Out:
#       medv         Estimator         Error
#  Min.   : 5.00   Min.   :13.31   Min.   :-22.18074
#  1st Qu.:17.02   1st Qu.:17.93   1st Qu.: -1.99554
#  Median :21.20   Median :21.01   Median :  0.35029
#  Mean   :22.53   Mean   :22.49   Mean   : -0.04008
#  3rd Qu.:25.00   3rd Qu.:24.45   3rd Qu.:  2.22286
#  Max.   :50.00   Max.   :43.96   Max.   : 11.06503
# [1] 0.1485856

# %% [markdown]
# # SQL Code Generation

# %%
test_ws_sql_gen = function(mod) {
    WS_URL = "https://sklearn2sql.herokuapp.com/model"
    WS_URL = "http://localhost:1888/model"
    model_serialized <- serialize(mod, NULL)
    b64_data = base64encode(model_serialized)
    data = list(Name = "xgboost_test_model", SerializedModel = b64_data , SQLDialect = "postgresql" , Mode="caret")
    r = POST(WS_URL, body = data, encode = "json")
    # print(r)
    content = content(r)
    # print(content)
    lSQL = content$model$SQLGenrationResult[[1]]$SQL # content["model"]["SQLGenrationResult"][0]["SQL"]
    return(lSQL);
}

# %%
lModelSQL = test_ws_sql_gen(model)
cat(lModelSQL)
# Out:
# WITH "RF_0" AS
# (WITH "DT_node_lookup" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.545000000000002) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_5" <= 6.803) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6825) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6635) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.93867403314917 AS "E" UNION ALL SELECT 6 AS nid, 14.163963963963955 AS "E" UNION ALL SELECT 7 AS nid, 24.83834586466165 AS "E" UNION ALL SELECT 8 AS nid, 32.282692307692315 AS "E" UNION ALL SELECT 9 AS nid, 45.38214285714286 AS "E" UNION ALL SELECT 10 AS nid, 21.9 AS "E") AS "Values"),
# "DT_Output" AS
# (SELECT "DT_node_lookup"."KEY" AS "KEY", "DT_node_lookup".node_id_2 AS node_id_2, "DT_node_data".nid AS nid, "DT_node_data"."E" AS "E"
# FROM "DT_node_lookup" LEFT OUTER JOIN "DT_node_data" ON "DT_node_lookup".node_id_2 = "DT_node_data".nid),
# "RF_Model_0" AS
# (SELECT "DT_Output"."KEY" AS "KEY", "DT_Output"."E" AS "Estimator"
# FROM "DT_Output"),
# "DT_node_lookup_1" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_0" <= 6.68632) THEN CASE WHEN ("ADS"."Feature_5" <= 6.722) THEN CASE WHEN ("ADS"."Feature_11" <= 348.53) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.435) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.645) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_1" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 16.344827586206893 AS "E" UNION ALL SELECT 6 AS nid, 11.328333333333333 AS "E" UNION ALL SELECT 7 AS nid, 16.750980392156862 AS "E" UNION ALL SELECT 8 AS nid, 21.86272401433692 AS "E" UNION ALL SELECT 9 AS nid, 31.795588235294122 AS "E" UNION ALL SELECT 10 AS nid, 43.29473684210527 AS "E") AS "Values"),
# "DT_Output_1" AS
# (SELECT "DT_node_lookup_1"."KEY" AS "KEY", "DT_node_lookup_1".node_id_2 AS node_id_2, "DT_node_data_1".nid AS nid, "DT_node_data_1"."E" AS "E"
# FROM "DT_node_lookup_1" LEFT OUTER JOIN "DT_node_data_1" ON "DT_node_lookup_1".node_id_2 = "DT_node_data_1".nid),
# "RF_Model_1" AS
# (SELECT "DT_Output_1"."KEY" AS "KEY", "DT_Output_1"."E" AS "Estimator"
# FROM "DT_Output_1"),
# "DT_node_lookup_2" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.92) THEN CASE WHEN ("ADS"."Feature_0" <= 5.790115) THEN CASE WHEN ("ADS"."Feature_0" <= 0.144655) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_7" <= 1.1736) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_2" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 32.933928571428574 AS "E" UNION ALL SELECT 6 AS nid, 45.73846153846154 AS "E" UNION ALL SELECT 7 AS nid, 23.18679245283019 AS "E" UNION ALL SELECT 8 AS nid, 19.281666666666666 AS "E" UNION ALL SELECT 9 AS nid, 37.93333333333334 AS "E" UNION ALL SELECT 10 AS nid, 12.764634146341464 AS "E") AS "Values"),
# "DT_Output_2" AS
# (SELECT "DT_node_lookup_2"."KEY" AS "KEY", "DT_node_lookup_2".node_id_2 AS node_id_2, "DT_node_data_2".nid AS nid, "DT_node_data_2"."E" AS "E"
# FROM "DT_node_lookup_2" LEFT OUTER JOIN "DT_node_data_2" ON "DT_node_lookup_2".node_id_2 = "DT_node_data_2".nid),
# "RF_Model_2" AS
# (SELECT "DT_Output_2"."KEY" AS "KEY", "DT_Output_2"."E" AS "Estimator"
# FROM "DT_Output_2"),
# "DT_node_lookup_3" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 7.865) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_7" <= 1.48495) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_11" <= 361.925) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.665) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_3" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.21244444444445 AS "E" UNION ALL SELECT 6 AS nid, 13.014736842105265 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 28.11266666666667 AS "E" UNION ALL SELECT 9 AS nid, 21.9 AS "E" UNION ALL SELECT 10 AS nid, 46.58387096774194 AS "E") AS "Values"),
# "DT_Output_3" AS
# (SELECT "DT_node_lookup_3"."KEY" AS "KEY", "DT_node_lookup_3".node_id_2 AS node_id_2, "DT_node_data_3".nid AS nid, "DT_node_data_3"."E" AS "E"
# FROM "DT_node_lookup_3" LEFT OUTER JOIN "DT_node_data_3" ON "DT_node_lookup_3".node_id_2 = "DT_node_data_3".nid),
# "RF_Model_3" AS
# (SELECT "DT_Output_3"."KEY" AS "KEY", "DT_Output_3"."E" AS "Estimator"
# FROM "DT_Output_3"),
# "DT_node_lookup_4" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 4.91) THEN CASE WHEN ("ADS"."Feature_10" <= 14.8) THEN CASE WHEN ("ADS"."Feature_5" <= 7.705999999999999) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_8" <= 7.5) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 14.445) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_4" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 23.856410256410257 AS "E" UNION ALL SELECT 6 AS nid, 15.2569696969697 AS "E" UNION ALL SELECT 7 AS nid, 43.975 AS "E" UNION ALL SELECT 8 AS nid, 50.0 AS "E" UNION ALL SELECT 9 AS nid, 34.17727272727273 AS "E" UNION ALL SELECT 10 AS nid, 46.86363636363635 AS "E") AS "Values"),
# "DT_Output_4" AS
# (SELECT "DT_node_lookup_4"."KEY" AS "KEY", "DT_node_lookup_4".node_id_2 AS node_id_2, "DT_node_data_4".nid AS nid, "DT_node_data_4"."E" AS "E"
# FROM "DT_node_lookup_4" LEFT OUTER JOIN "DT_node_data_4" ON "DT_node_lookup_4".node_id_2 = "DT_node_data_4".nid),
# "RF_Model_4" AS
# (SELECT "DT_Output_4"."KEY" AS "KEY", "DT_Output_4"."E" AS "Estimator"
# FROM "DT_Output_4"),
# "DT_node_lookup_5" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_2" <= 6.66) THEN CASE WHEN ("ADS"."Feature_12" <= 5.265000000000001) THEN CASE WHEN ("ADS"."Feature_5" <= 7.433) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_0" <= 0.410045) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 4.135) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_5" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 50.0 AS "E" UNION ALL SELECT 6 AS nid, 18.070347003154573 AS "E" UNION ALL SELECT 7 AS nid, 31.964102564102568 AS "E" UNION ALL SELECT 8 AS nid, 45.74285714285714 AS "E" UNION ALL SELECT 9 AS nid, 23.36448598130841 AS "E" UNION ALL SELECT 10 AS nid, 32.43 AS "E") AS "Values"),
# "DT_Output_5" AS
# (SELECT "DT_node_lookup_5"."KEY" AS "KEY", "DT_node_lookup_5".node_id_2 AS node_id_2, "DT_node_data_5".nid AS nid, "DT_node_data_5"."E" AS "E"
# FROM "DT_node_lookup_5" LEFT OUTER JOIN "DT_node_data_5" ON "DT_node_lookup_5".node_id_2 = "DT_node_data_5".nid),
# "RF_Model_5" AS
# (SELECT "DT_Output_5"."KEY" AS "KEY", "DT_Output_5"."E" AS "Estimator"
# FROM "DT_Output_5"),
# "DT_node_lookup_6" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 7.685) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_5" <= 6.8725000000000005) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_8" <= 16.0) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 15.0) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_6" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 22.069473684210525 AS "E" UNION ALL SELECT 6 AS nid, 14.477987421383649 AS "E" UNION ALL SELECT 7 AS nid, 26.27777777777777 AS "E" UNION ALL SELECT 8 AS nid, 33.333333333333336 AS "E" UNION ALL SELECT 9 AS nid, 45.61666666666667 AS "E" UNION ALL SELECT 10 AS nid, 21.9 AS "E") AS "Values"),
# "DT_Output_6" AS
# (SELECT "DT_node_lookup_6"."KEY" AS "KEY", "DT_node_lookup_6".node_id_2 AS node_id_2, "DT_node_data_6".nid AS nid, "DT_node_data_6"."E" AS "E"
# FROM "DT_node_lookup_6" LEFT OUTER JOIN "DT_node_data_6" ON "DT_node_lookup_6".node_id_2 = "DT_node_data_6".nid),
# "RF_Model_6" AS
# (SELECT "DT_Output_6"."KEY" AS "KEY", "DT_Output_6"."E" AS "Estimator"
# FROM "DT_Output_6"),
# "DT_node_lookup_7" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.9715) THEN CASE WHEN ("ADS"."Feature_12" <= 9.725) THEN CASE WHEN ("ADS"."Feature_6" <= 89.04999999999998) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_9" <= 434.5) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.47) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_7" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 31.776744186046514 AS "E" UNION ALL SELECT 6 AS nid, 45.9875 AS "E" UNION ALL SELECT 7 AS nid, 24.905147058823534 AS "E" UNION ALL SELECT 8 AS nid, 37.83076923076923 AS "E" UNION ALL SELECT 9 AS nid, 19.59873417721519 AS "E" UNION ALL SELECT 10 AS nid, 15.070454545454545 AS "E") AS "Values"),
# "DT_Output_7" AS
# (SELECT "DT_node_lookup_7"."KEY" AS "KEY", "DT_node_lookup_7".node_id_2 AS node_id_2, "DT_node_data_7".nid AS nid, "DT_node_data_7"."E" AS "E"
# FROM "DT_node_lookup_7" LEFT OUTER JOIN "DT_node_data_7" ON "DT_node_lookup_7".node_id_2 = "DT_node_data_7".nid),
# "RF_Model_7" AS
# (SELECT "DT_Output_7"."KEY" AS "KEY", "DT_Output_7"."E" AS "Estimator"
# FROM "DT_Output_7"),
# "DT_node_lookup_8" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 4.915) THEN CASE WHEN ("ADS"."Feature_5" <= 7.405999999999999) THEN CASE WHEN ("ADS"."Feature_4" <= 0.5875) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_10" <= 14.8) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 14.795) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_8" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 23.692439862542955 AS "E" UNION ALL SELECT 6 AS nid, 14.610457516339867 AS "E" UNION ALL SELECT 7 AS nid, 31.645945945945943 AS "E" UNION ALL SELECT 8 AS nid, 50.0 AS "E" UNION ALL SELECT 9 AS nid, 48.977777777777774 AS "E" UNION ALL SELECT 10 AS nid, 46.43846153846154 AS "E") AS "Values"),
# "DT_Output_8" AS
# (SELECT "DT_node_lookup_8"."KEY" AS "KEY", "DT_node_lookup_8".node_id_2 AS node_id_2, "DT_node_data_8".nid AS nid, "DT_node_data_8"."E" AS "E"
# FROM "DT_node_lookup_8" LEFT OUTER JOIN "DT_node_data_8" ON "DT_node_lookup_8".node_id_2 = "DT_node_data_8".nid),
# "RF_Model_8" AS
# (SELECT "DT_Output_8"."KEY" AS "KEY", "DT_Output_8"."E" AS "Estimator"
# FROM "DT_Output_8"),
# "DT_node_lookup_9" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 7.13) THEN CASE WHEN ("ADS"."Feature_5" <= 7.445) THEN CASE WHEN ("ADS"."Feature_10" <= 19.4) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_11" <= 364.49) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 5.8466000000000005) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_9" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.473507462686566 AS "E" UNION ALL SELECT 6 AS nid, 13.318 AS "E" UNION ALL SELECT 7 AS nid, 30.398979591836728 AS "E" UNION ALL SELECT 8 AS nid, 22.85384615384616 AS "E" UNION ALL SELECT 9 AS nid, 21.9 AS "E" UNION ALL SELECT 10 AS nid, 45.49583333333333 AS "E") AS "Values"),
# "DT_Output_9" AS
# (SELECT "DT_node_lookup_9"."KEY" AS "KEY", "DT_node_lookup_9".node_id_2 AS node_id_2, "DT_node_data_9".nid AS nid, "DT_node_data_9"."E" AS "E"
# FROM "DT_node_lookup_9" LEFT OUTER JOIN "DT_node_data_9" ON "DT_node_lookup_9".node_id_2 = "DT_node_data_9".nid),
# "RF_Model_9" AS
# (SELECT "DT_Output_9"."KEY" AS "KEY", "DT_Output_9"."E" AS "Estimator"
# FROM "DT_Output_9")
#  SELECT "RF_esu_0"."KEY", "RF_esu_0"."Estimator"
# FROM (SELECT "RF_Model_0"."KEY" AS "KEY", CAST("RF_Model_0"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_0" UNION ALL SELECT "RF_Model_1"."KEY" AS "KEY", CAST("RF_Model_1"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_1" UNION ALL SELECT "RF_Model_2"."KEY" AS "KEY", CAST("RF_Model_2"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_2" UNION ALL SELECT "RF_Model_3"."KEY" AS "KEY", CAST("RF_Model_3"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_3" UNION ALL SELECT "RF_Model_4"."KEY" AS "KEY", CAST("RF_Model_4"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_4" UNION ALL SELECT "RF_Model_5"."KEY" AS "KEY", CAST("RF_Model_5"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_5" UNION ALL SELECT "RF_Model_6"."KEY" AS "KEY", CAST("RF_Model_6"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_6" UNION ALL SELECT "RF_Model_7"."KEY" AS "KEY", CAST("RF_Model_7"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_7" UNION ALL SELECT "RF_Model_8"."KEY" AS "KEY", CAST("RF_Model_8"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_8" UNION ALL SELECT "RF_Model_9"."KEY" AS "KEY", CAST("RF_Model_9"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_9") AS "RF_esu_0"),
# "RF_1" AS
# (WITH "DT_node_lookup_10" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 8.934999999999999) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_7" <= 1.48495) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.7835) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 7.947554999999999) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_10" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.910041841004183 AS "E" UNION ALL SELECT 6 AS nid, 11.874999999999995 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 27.329285714285717 AS "E" UNION ALL SELECT 9 AS nid, 41.8 AS "E" UNION ALL SELECT 10 AS nid, 46.46666666666666 AS "E") AS "Values"),
# "DT_Output_10" AS
# (SELECT "DT_node_lookup_10"."KEY" AS "KEY", "DT_node_lookup_10".node_id_2 AS node_id_2, "DT_node_data_10".nid AS nid, "DT_node_data_10"."E" AS "E"
# FROM "DT_node_lookup_10" LEFT OUTER JOIN "DT_node_data_10" ON "DT_node_lookup_10".node_id_2 = "DT_node_data_10".nid),
# "RF_Model_10" AS
# (SELECT "DT_Output_10"."KEY" AS "KEY", "DT_Output_10"."E" AS "Estimator"
# FROM "DT_Output_10"),
# "DT_node_lookup_11" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.67) THEN CASE WHEN ("ADS"."Feature_12" <= 14.399999999999999) THEN CASE WHEN ("ADS"."Feature_7" <= 1.22715) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.657) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.442999999999999) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_11" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 29.728235294117646 AS "E" UNION ALL SELECT 6 AS nid, 45.35238095238096 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 22.157345971563977 AS "E" UNION ALL SELECT 9 AS nid, 17.434285714285714 AS "E" UNION ALL SELECT 10 AS nid, 12.144444444444444 AS "E") AS "Values"),
# "DT_Output_11" AS
# (SELECT "DT_node_lookup_11"."KEY" AS "KEY", "DT_node_lookup_11".node_id_2 AS node_id_2, "DT_node_data_11".nid AS nid, "DT_node_data_11"."E" AS "E"
# FROM "DT_node_lookup_11" LEFT OUTER JOIN "DT_node_data_11" ON "DT_node_lookup_11".node_id_2 = "DT_node_data_11".nid),
# "RF_Model_11" AS
# (SELECT "DT_Output_11"."KEY" AS "KEY", "DT_Output_11"."E" AS "Estimator"
# FROM "DT_Output_11"),
# "DT_node_lookup_12" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.7815) THEN CASE WHEN ("ADS"."Feature_12" <= 14.26) THEN CASE WHEN ("ADS"."Feature_7" <= 1.5449000000000002) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_0" <= 7.46495) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.445) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_12" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 30.96666666666667 AS "E" UNION ALL SELECT 6 AS nid, 46.04666666666666 AS "E" UNION ALL SELECT 7 AS nid, 40.52857142857143 AS "E" UNION ALL SELECT 8 AS nid, 22.374235807860266 AS "E" UNION ALL SELECT 9 AS nid, 17.14190476190476 AS "E" UNION ALL SELECT 10 AS nid, 11.714492753623187 AS "E") AS "Values"),
# "DT_Output_12" AS
# (SELECT "DT_node_lookup_12"."KEY" AS "KEY", "DT_node_lookup_12".node_id_2 AS node_id_2, "DT_node_data_12".nid AS nid, "DT_node_data_12"."E" AS "E"
# FROM "DT_node_lookup_12" LEFT OUTER JOIN "DT_node_data_12" ON "DT_node_lookup_12".node_id_2 = "DT_node_data_12".nid),
# "RF_Model_12" AS
# (SELECT "DT_Output_12"."KEY" AS "KEY", "DT_Output_12"."E" AS "Estimator"
# FROM "DT_Output_12"),
# "DT_node_lookup_13" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_10" <= 19.9) THEN CASE WHEN ("ADS"."Feature_12" <= 8.129999999999999) THEN CASE WHEN ("ADS"."Feature_0" <= 1.4031) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_6" <= 85.29999999999998) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 6.88166) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_13" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.17913043478261 AS "E" UNION ALL SELECT 6 AS nid, 12.604166666666664 AS "E" UNION ALL SELECT 7 AS nid, 32.6844262295082 AS "E" UNION ALL SELECT 8 AS nid, 50.0 AS "E" UNION ALL SELECT 9 AS nid, 22.07666666666667 AS "E" UNION ALL SELECT 10 AS nid, 16.778723404255313 AS "E") AS "Values"),
# "DT_Output_13" AS
# (SELECT "DT_node_lookup_13"."KEY" AS "KEY", "DT_node_lookup_13".node_id_2 AS node_id_2, "DT_node_data_13".nid AS nid, "DT_node_data_13"."E" AS "E"
# FROM "DT_node_lookup_13" LEFT OUTER JOIN "DT_node_data_13" ON "DT_node_lookup_13".node_id_2 = "DT_node_data_13".nid),
# "RF_Model_13" AS
# (SELECT "DT_Output_13"."KEY" AS "KEY", "DT_Output_13"."E" AS "Estimator"
# FROM "DT_Output_13"),
# "DT_node_lookup_14" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.755) THEN CASE WHEN ("ADS"."Feature_10" <= 15.05) THEN CASE WHEN ("ADS"."Feature_5" <= 7.3785) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_7" <= 1.8221) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 6.91188) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_14" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.116062176165805 AS "E" UNION ALL SELECT 6 AS nid, 12.983529411764708 AS "E" UNION ALL SELECT 7 AS nid, 32.07857142857143 AS "E" UNION ALL SELECT 8 AS nid, 47.62083333333334 AS "E" UNION ALL SELECT 9 AS nid, 50.0 AS "E" UNION ALL SELECT 10 AS nid, 27.260326086956525 AS "E") AS "Values"),
# "DT_Output_14" AS
# (SELECT "DT_node_lookup_14"."KEY" AS "KEY", "DT_node_lookup_14".node_id_2 AS node_id_2, "DT_node_data_14".nid AS nid, "DT_node_data_14"."E" AS "E"
# FROM "DT_node_lookup_14" LEFT OUTER JOIN "DT_node_data_14" ON "DT_node_lookup_14".node_id_2 = "DT_node_data_14".nid),
# "RF_Model_14" AS
# (SELECT "DT_Output_14"."KEY" AS "KEY", "DT_Output_14"."E" AS "Estimator"
# FROM "DT_Output_14"),
# "DT_node_lookup_15" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_2" <= 6.66) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_5" <= 6.711) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 3.69) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6695) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_15" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 21.241395348837205 AS "E" UNION ALL SELECT 6 AS nid, 13.532352941176459 AS "E" UNION ALL SELECT 7 AS nid, 22.8340206185567 AS "E" UNION ALL SELECT 8 AS nid, 31.027142857142863 AS "E" UNION ALL SELECT 9 AS nid, 43.66923076923078 AS "E" UNION ALL SELECT 10 AS nid, 49.27777777777778 AS "E") AS "Values"),
# "DT_Output_15" AS
# (SELECT "DT_node_lookup_15"."KEY" AS "KEY", "DT_node_lookup_15".node_id_2 AS node_id_2, "DT_node_data_15".nid AS nid, "DT_node_data_15"."E" AS "E"
# FROM "DT_node_lookup_15" LEFT OUTER JOIN "DT_node_data_15" ON "DT_node_lookup_15".node_id_2 = "DT_node_data_15".nid),
# "RF_Model_15" AS
# (SELECT "DT_Output_15"."KEY" AS "KEY", "DT_Output_15"."E" AS "Estimator"
# FROM "DT_Output_15"),
# "DT_node_lookup_16" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 11.69) THEN CASE WHEN ("ADS"."Feature_7" <= 2.16475) THEN CASE WHEN ("ADS"."Feature_0" <= 1.4031) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 4.915) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 5.769209999999999) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_16" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.136231884057967 AS "E" UNION ALL SELECT 6 AS nid, 12.718085106382976 AS "E" UNION ALL SELECT 7 AS nid, 32.41428571428571 AS "E" UNION ALL SELECT 8 AS nid, 47.5 AS "E" UNION ALL SELECT 9 AS nid, 36.4642857142857 AS "E" UNION ALL SELECT 10 AS nid, 25.10143540669857 AS "E") AS "Values"),
# "DT_Output_16" AS
# (SELECT "DT_node_lookup_16"."KEY" AS "KEY", "DT_node_lookup_16".node_id_2 AS node_id_2, "DT_node_data_16".nid AS nid, "DT_node_data_16"."E" AS "E"
# FROM "DT_node_lookup_16" LEFT OUTER JOIN "DT_node_data_16" ON "DT_node_lookup_16".node_id_2 = "DT_node_data_16".nid),
# "RF_Model_16" AS
# (SELECT "DT_Output_16"."KEY" AS "KEY", "DT_Output_16"."E" AS "Estimator"
# FROM "DT_Output_16"),
# "DT_node_lookup_17" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.615) THEN CASE WHEN ("ADS"."Feature_5" <= 6.9055) THEN CASE WHEN ("ADS"."Feature_6" <= 96.2) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 3.99) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 19.83) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_17" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.479372197309413 AS "E" UNION ALL SELECT 6 AS nid, 12.117333333333328 AS "E" UNION ALL SELECT 7 AS nid, 24.37175572519084 AS "E" UNION ALL SELECT 8 AS nid, 50.0 AS "E" UNION ALL SELECT 9 AS nid, 46.54666666666668 AS "E" UNION ALL SELECT 10 AS nid, 35.385714285714286 AS "E") AS "Values"),
# "DT_Output_17" AS
# (SELECT "DT_node_lookup_17"."KEY" AS "KEY", "DT_node_lookup_17".node_id_2 AS node_id_2, "DT_node_data_17".nid AS nid, "DT_node_data_17"."E" AS "E"
# FROM "DT_node_lookup_17" LEFT OUTER JOIN "DT_node_data_17" ON "DT_node_lookup_17".node_id_2 = "DT_node_data_17".nid),
# "RF_Model_17" AS
# (SELECT "DT_Output_17"."KEY" AS "KEY", "DT_Output_17"."E" AS "Estimator"
# FROM "DT_Output_17"),
# "DT_node_lookup_18" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.9715) THEN CASE WHEN ("ADS"."Feature_12" <= 14.3) THEN CASE WHEN ("ADS"."Feature_5" <= 6.543) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_0" <= 9.773835) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_18" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 32.302439024390246 AS "E" UNION ALL SELECT 6 AS nid, 45.225 AS "E" UNION ALL SELECT 7 AS nid, 22.096089385474855 AS "E" UNION ALL SELECT 8 AS nid, 27.621875 AS "E" UNION ALL SELECT 9 AS nid, 16.930656934306565 AS "E" UNION ALL SELECT 10 AS nid, 10.35438596491228 AS "E") AS "Values"),
# "DT_Output_18" AS
# (SELECT "DT_node_lookup_18"."KEY" AS "KEY", "DT_node_lookup_18".node_id_2 AS node_id_2, "DT_node_data_18".nid AS nid, "DT_node_data_18"."E" AS "E"
# FROM "DT_node_lookup_18" LEFT OUTER JOIN "DT_node_data_18" ON "DT_node_lookup_18".node_id_2 = "DT_node_data_18".nid),
# "RF_Model_18" AS
# (SELECT "DT_Output_18"."KEY" AS "KEY", "DT_Output_18"."E" AS "Estimator"
# FROM "DT_Output_18"),
# "DT_node_lookup_19" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 7.685) THEN CASE WHEN ("ADS"."Feature_5" <= 7.445) THEN CASE WHEN ("ADS"."Feature_7" <= 1.48495) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_10" <= 16.149999999999995) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_7" <= 2.0037000000000003) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_19" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 14.021052631578947 AS "E" UNION ALL SELECT 6 AS nid, 20.385328185328184 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 27.31111111111111 AS "E" UNION ALL SELECT 9 AS nid, 48.05 AS "E" UNION ALL SELECT 10 AS nid, 41.25454545454546 AS "E") AS "Values"),
# "DT_Output_19" AS
# (SELECT "DT_node_lookup_19"."KEY" AS "KEY", "DT_node_lookup_19".node_id_2 AS node_id_2, "DT_node_data_19".nid AS nid, "DT_node_data_19"."E" AS "E"
# FROM "DT_node_lookup_19" LEFT OUTER JOIN "DT_node_data_19" ON "DT_node_lookup_19".node_id_2 = "DT_node_data_19".nid),
# "RF_Model_19" AS
# (SELECT "DT_Output_19"."KEY" AS "KEY", "DT_Output_19"."E" AS "Estimator"
# FROM "DT_Output_19")
#  SELECT "RF_esu_1"."KEY", "RF_esu_1"."Estimator"
# FROM (SELECT "RF_Model_10"."KEY" AS "KEY", CAST("RF_Model_10"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_10" UNION ALL SELECT "RF_Model_11"."KEY" AS "KEY", CAST("RF_Model_11"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_11" UNION ALL SELECT "RF_Model_12"."KEY" AS "KEY", CAST("RF_Model_12"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_12" UNION ALL SELECT "RF_Model_13"."KEY" AS "KEY", CAST("RF_Model_13"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_13" UNION ALL SELECT "RF_Model_14"."KEY" AS "KEY", CAST("RF_Model_14"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_14" UNION ALL SELECT "RF_Model_15"."KEY" AS "KEY", CAST("RF_Model_15"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_15" UNION ALL SELECT "RF_Model_16"."KEY" AS "KEY", CAST("RF_Model_16"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_16" UNION ALL SELECT "RF_Model_17"."KEY" AS "KEY", CAST("RF_Model_17"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_17" UNION ALL SELECT "RF_Model_18"."KEY" AS "KEY", CAST("RF_Model_18"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_18" UNION ALL SELECT "RF_Model_19"."KEY" AS "KEY", CAST("RF_Model_19"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_19") AS "RF_esu_1"),
# "RF_2" AS
# (WITH "DT_node_lookup_20" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.95) THEN CASE WHEN ("ADS"."Feature_5" <= 6.911) THEN CASE WHEN ("ADS"."Feature_7" <= 1.47285) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 5.1850000000000005) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 16.295) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_20" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.15592105263158 AS "E" UNION ALL SELECT 6 AS nid, 14.208823529411767 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 24.397959183673468 AS "E" UNION ALL SELECT 9 AS nid, 42.62702702702703 AS "E" UNION ALL SELECT 10 AS nid, 36.322580645161295 AS "E") AS "Values"),
# "DT_Output_20" AS
# (SELECT "DT_node_lookup_20"."KEY" AS "KEY", "DT_node_lookup_20".node_id_2 AS node_id_2, "DT_node_data_20".nid AS nid, "DT_node_data_20"."E" AS "E"
# FROM "DT_node_lookup_20" LEFT OUTER JOIN "DT_node_data_20" ON "DT_node_lookup_20".node_id_2 = "DT_node_data_20".nid),
# "RF_Model_20" AS
# (SELECT "DT_Output_20"."KEY" AS "KEY", "DT_Output_20"."E" AS "Estimator"
# FROM "DT_Output_20"),
# "DT_node_lookup_21" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 8.984999999999998) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_7" <= 1.48495) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_6" <= 90.1) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 6.68632) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_21" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.044725738396625 AS "E" UNION ALL SELECT 6 AS nid, 12.034831460674155 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 27.313013698630137 AS "E" UNION ALL SELECT 9 AS nid, 44.79565217391304 AS "E" UNION ALL SELECT 10 AS nid, 49.52 AS "E") AS "Values"),
# "DT_Output_21" AS
# (SELECT "DT_node_lookup_21"."KEY" AS "KEY", "DT_node_lookup_21".node_id_2 AS node_id_2, "DT_node_data_21".nid AS nid, "DT_node_data_21"."E" AS "E"
# FROM "DT_node_lookup_21" LEFT OUTER JOIN "DT_node_data_21" ON "DT_node_lookup_21".node_id_2 = "DT_node_data_21".nid),
# "RF_Model_21" AS
# (SELECT "DT_Output_21"."KEY" AS "KEY", "DT_Output_21"."E" AS "Estimator"
# FROM "DT_Output_21"),
# "DT_node_lookup_22" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.745) THEN CASE WHEN ("ADS"."Feature_5" <= 7.468) THEN CASE WHEN ("ADS"."Feature_6" <= 95.0) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 8.752499999999998) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 17.274999999999995) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_22" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.764327485380115 AS "E" UNION ALL SELECT 6 AS nid, 13.275833333333335 AS "E" UNION ALL SELECT 7 AS nid, 26.722598870056494 AS "E" UNION ALL SELECT 8 AS nid, 44.1 AS "E" UNION ALL SELECT 9 AS nid, 46.29666666666666 AS "E" UNION ALL SELECT 10 AS nid, 21.9 AS "E") AS "Values"),
# "DT_Output_22" AS
# (SELECT "DT_node_lookup_22"."KEY" AS "KEY", "DT_node_lookup_22".node_id_2 AS node_id_2, "DT_node_data_22".nid AS nid, "DT_node_data_22"."E" AS "E"
# FROM "DT_node_lookup_22" LEFT OUTER JOIN "DT_node_data_22" ON "DT_node_lookup_22".node_id_2 = "DT_node_data_22".nid),
# "RF_Model_22" AS
# (SELECT "DT_Output_22"."KEY" AS "KEY", "DT_Output_22"."E" AS "Estimator"
# FROM "DT_Output_22"),
# "DT_node_lookup_23" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_2" <= 6.66) THEN CASE WHEN ("ADS"."Feature_9" <= 277.5) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 6.772) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 4.835) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_23" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 46.73 AS "E" UNION ALL SELECT 6 AS nid, 18.620064724919093 AS "E" UNION ALL SELECT 7 AS nid, 29.451724137931038 AS "E" UNION ALL SELECT 8 AS nid, 45.105263157894726 AS "E" UNION ALL SELECT 9 AS nid, 22.632467532467533 AS "E" UNION ALL SELECT 10 AS nid, 34.6 AS "E") AS "Values"),
# "DT_Output_23" AS
# (SELECT "DT_node_lookup_23"."KEY" AS "KEY", "DT_node_lookup_23".node_id_2 AS node_id_2, "DT_node_data_23".nid AS nid, "DT_node_data_23"."E" AS "E"
# FROM "DT_node_lookup_23" LEFT OUTER JOIN "DT_node_data_23" ON "DT_node_lookup_23".node_id_2 = "DT_node_data_23".nid),
# "RF_Model_23" AS
# (SELECT "DT_Output_23"."KEY" AS "KEY", "DT_Output_23"."E" AS "Estimator"
# FROM "DT_Output_23"),
# "DT_node_lookup_24" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 5.265000000000001) THEN CASE WHEN ("ADS"."Feature_5" <= 7.433) THEN CASE WHEN ("ADS"."Feature_7" <= 2.28895) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_11" <= 383.525) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 14.92) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_24" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 23.17582417582417 AS "E" UNION ALL SELECT 6 AS nid, 15.136585365853655 AS "E" UNION ALL SELECT 7 AS nid, 48.55 AS "E" UNION ALL SELECT 8 AS nid, 31.99230769230769 AS "E" UNION ALL SELECT 9 AS nid, 48.714285714285715 AS "E" UNION ALL SELECT 10 AS nid, 43.417647058823526 AS "E") AS "Values"),
# "DT_Output_24" AS
# (SELECT "DT_node_lookup_24"."KEY" AS "KEY", "DT_node_lookup_24".node_id_2 AS node_id_2, "DT_node_data_24".nid AS nid, "DT_node_data_24"."E" AS "E"
# FROM "DT_node_lookup_24" LEFT OUTER JOIN "DT_node_data_24" ON "DT_node_lookup_24".node_id_2 = "DT_node_data_24".nid),
# "RF_Model_24" AS
# (SELECT "DT_Output_24"."KEY" AS "KEY", "DT_Output_24"."E" AS "Estimator"
# FROM "DT_Output_24"),
# "DT_node_lookup_25" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_2" <= 6.66) THEN CASE WHEN ("ADS"."Feature_7" <= 5.93515) THEN CASE WHEN ("ADS"."Feature_12" <= 5.1850000000000005) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_10" <= 15.75) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 6.8465) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_25" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 18.17582781456953 AS "E" UNION ALL SELECT 6 AS nid, 38.91333333333333 AS "E" UNION ALL SELECT 7 AS nid, 40.25777777777779 AS "E" UNION ALL SELECT 8 AS nid, 26.555714285714284 AS "E" UNION ALL SELECT 9 AS nid, 29.37333333333333 AS "E" UNION ALL SELECT 10 AS nid, 23.252542372881354 AS "E") AS "Values"),
# "DT_Output_25" AS
# (SELECT "DT_node_lookup_25"."KEY" AS "KEY", "DT_node_lookup_25".node_id_2 AS node_id_2, "DT_node_data_25".nid AS nid, "DT_node_data_25"."E" AS "E"
# FROM "DT_node_lookup_25" LEFT OUTER JOIN "DT_node_data_25" ON "DT_node_lookup_25".node_id_2 = "DT_node_data_25".nid),
# "RF_Model_25" AS
# (SELECT "DT_Output_25"."KEY" AS "KEY", "DT_Output_25"."E" AS "Estimator"
# FROM "DT_Output_25"),
# "DT_node_lookup_26" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.9715) THEN CASE WHEN ("ADS"."Feature_0" <= 5.8466000000000005) THEN CASE WHEN ("ADS"."Feature_12" <= 7.685) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.641) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_26" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 31.88409090909091 AS "E" UNION ALL SELECT 6 AS nid, 46.23823529411765 AS "E" UNION ALL SELECT 7 AS nid, 26.881318681318678 AS "E" UNION ALL SELECT 8 AS nid, 19.691139240506327 AS "E" UNION ALL SELECT 9 AS nid, 16.875 AS "E" UNION ALL SELECT 10 AS nid, 11.857894736842105 AS "E") AS "Values"),
# "DT_Output_26" AS
# (SELECT "DT_node_lookup_26"."KEY" AS "KEY", "DT_node_lookup_26".node_id_2 AS node_id_2, "DT_node_data_26".nid AS nid, "DT_node_data_26"."E" AS "E"
# FROM "DT_node_lookup_26" LEFT OUTER JOIN "DT_node_data_26" ON "DT_node_lookup_26".node_id_2 = "DT_node_data_26".nid),
# "RF_Model_26" AS
# (SELECT "DT_Output_26"."KEY" AS "KEY", "DT_Output_26"."E" AS "Estimator"
# FROM "DT_Output_26"),
# "DT_node_lookup_27" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_10" <= 19.65) THEN CASE WHEN ("ADS"."Feature_2" <= 6.66) THEN CASE WHEN ("ADS"."Feature_12" <= 4.65) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.738) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6635) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_27" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.677876106194688 AS "E" UNION ALL SELECT 6 AS nid, 14.002197802197804 AS "E" UNION ALL SELECT 7 AS nid, 39.58936170212766 AS "E" UNION ALL SELECT 8 AS nid, 26.208 AS "E" UNION ALL SELECT 9 AS nid, 23.198214285714286 AS "E" UNION ALL SELECT 10 AS nid, 16.738888888888894 AS "E") AS "Values"),
# "DT_Output_27" AS
# (SELECT "DT_node_lookup_27"."KEY" AS "KEY", "DT_node_lookup_27".node_id_2 AS node_id_2, "DT_node_data_27".nid AS nid, "DT_node_data_27"."E" AS "E"
# FROM "DT_node_lookup_27" LEFT OUTER JOIN "DT_node_data_27" ON "DT_node_lookup_27".node_id_2 = "DT_node_data_27".nid),
# "RF_Model_27" AS
# (SELECT "DT_Output_27"."KEY" AS "KEY", "DT_Output_27"."E" AS "Estimator"
# FROM "DT_Output_27"),
# "DT_node_lookup_28" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.95) THEN CASE WHEN ("ADS"."Feature_12" <= 4.83) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4235) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.113) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_7" <= 2.0643) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_28" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 13.164705882352939 AS "E" UNION ALL SELECT 6 AS nid, 19.49235294117647 AS "E" UNION ALL SELECT 7 AS nid, 34.445454545454545 AS "E" UNION ALL SELECT 8 AS nid, 46.8388888888889 AS "E" UNION ALL SELECT 9 AS nid, 25.444520547945213 AS "E" UNION ALL SELECT 10 AS nid, 38.72500000000001 AS "E") AS "Values"),
# "DT_Output_28" AS
# (SELECT "DT_node_lookup_28"."KEY" AS "KEY", "DT_node_lookup_28".node_id_2 AS node_id_2, "DT_node_data_28".nid AS nid, "DT_node_data_28"."E" AS "E"
# FROM "DT_node_lookup_28" LEFT OUTER JOIN "DT_node_data_28" ON "DT_node_lookup_28".node_id_2 = "DT_node_data_28".nid),
# "RF_Model_28" AS
# (SELECT "DT_Output_28"."KEY" AS "KEY", "DT_Output_28"."E" AS "Estimator"
# FROM "DT_Output_28"),
# "DT_node_lookup_29" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 7.58) THEN CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN CASE WHEN ("ADS"."Feature_8" <= 16.0) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6825) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 5.84803) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_29" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 20.380608365019008 AS "E" UNION ALL SELECT 6 AS nid, 12.822988505747125 AS "E" UNION ALL SELECT 7 AS nid, 28.294262295081968 AS "E" UNION ALL SELECT 8 AS nid, 45.83333333333333 AS "E" UNION ALL SELECT 9 AS nid, 45.50800000000001 AS "E" UNION ALL SELECT 10 AS nid, 21.9 AS "E") AS "Values"),
# "DT_Output_29" AS
# (SELECT "DT_node_lookup_29"."KEY" AS "KEY", "DT_node_lookup_29".node_id_2 AS node_id_2, "DT_node_data_29".nid AS nid, "DT_node_data_29"."E" AS "E"
# FROM "DT_node_lookup_29" LEFT OUTER JOIN "DT_node_data_29" ON "DT_node_lookup_29".node_id_2 = "DT_node_data_29".nid),
# "RF_Model_29" AS
# (SELECT "DT_Output_29"."KEY" AS "KEY", "DT_Output_29"."E" AS "Estimator"
# FROM "DT_Output_29")
#  SELECT "RF_esu_2"."KEY", "RF_esu_2"."Estimator"
# FROM (SELECT "RF_Model_20"."KEY" AS "KEY", CAST("RF_Model_20"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_20" UNION ALL SELECT "RF_Model_21"."KEY" AS "KEY", CAST("RF_Model_21"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_21" UNION ALL SELECT "RF_Model_22"."KEY" AS "KEY", CAST("RF_Model_22"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_22" UNION ALL SELECT "RF_Model_23"."KEY" AS "KEY", CAST("RF_Model_23"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_23" UNION ALL SELECT "RF_Model_24"."KEY" AS "KEY", CAST("RF_Model_24"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_24" UNION ALL SELECT "RF_Model_25"."KEY" AS "KEY", CAST("RF_Model_25"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_25" UNION ALL SELECT "RF_Model_26"."KEY" AS "KEY", CAST("RF_Model_26"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_26" UNION ALL SELECT "RF_Model_27"."KEY" AS "KEY", CAST("RF_Model_27"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_27" UNION ALL SELECT "RF_Model_28"."KEY" AS "KEY", CAST("RF_Model_28"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_28" UNION ALL SELECT "RF_Model_29"."KEY" AS "KEY", CAST("RF_Model_29"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_29") AS "RF_esu_2"),
# "RF_3" AS
# (WITH "DT_node_lookup_30" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.725) THEN CASE WHEN ("ADS"."Feature_5" <= 7.435) THEN CASE WHEN ("ADS"."Feature_7" <= 1.48495) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 5.85) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 6.925795) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_30" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.333649289099526 AS "E" UNION ALL SELECT 6 AS nid, 12.990322580645168 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 26.345930232558135 AS "E" UNION ALL SELECT 9 AS nid, 46.05454545454546 AS "E" UNION ALL SELECT 10 AS nid, 38.266666666666666 AS "E") AS "Values"),
# "DT_Output_30" AS
# (SELECT "DT_node_lookup_30"."KEY" AS "KEY", "DT_node_lookup_30".node_id_2 AS node_id_2, "DT_node_data_30".nid AS nid, "DT_node_data_30"."E" AS "E"
# FROM "DT_node_lookup_30" LEFT OUTER JOIN "DT_node_data_30" ON "DT_node_lookup_30".node_id_2 = "DT_node_data_30".nid),
# "RF_Model_30" AS
# (SELECT "DT_Output_30"."KEY" AS "KEY", "DT_Output_30"."E" AS "Estimator"
# FROM "DT_Output_30"),
# "DT_node_lookup_31" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.6785) THEN CASE WHEN ("ADS"."Feature_12" <= 14.805) THEN CASE WHEN ("ADS"."Feature_7" <= 1.2073999999999998) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_0" <= 7.46495) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 7.393424999999999) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_31" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 36.00388349514563 AS "E" UNION ALL SELECT 6 AS nid, 14.991666666666667 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 22.304910714285718 AS "E" UNION ALL SELECT 9 AS nid, 17.007547169811325 AS "E" UNION ALL SELECT 10 AS nid, 11.828333333333335 AS "E") AS "Values"),
# "DT_Output_31" AS
# (SELECT "DT_node_lookup_31"."KEY" AS "KEY", "DT_node_lookup_31".node_id_2 AS node_id_2, "DT_node_data_31".nid AS nid, "DT_node_data_31"."E" AS "E"
# FROM "DT_node_lookup_31" LEFT OUTER JOIN "DT_node_data_31" ON "DT_node_lookup_31".node_id_2 = "DT_node_data_31".nid),
# "RF_Model_31" AS
# (SELECT "DT_Output_31"."KEY" AS "KEY", "DT_Output_31"."E" AS "Estimator"
# FROM "DT_Output_31"),
# "DT_node_lookup_32" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.978) THEN CASE WHEN ("ADS"."Feature_4" <= 0.6695) THEN CASE WHEN ("ADS"."Feature_5" <= 6.543) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_0" <= 7.194850000000001) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.435) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_32" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 33.513513513513516 AS "E" UNION ALL SELECT 6 AS nid, 45.72000000000001 AS "E" UNION ALL SELECT 7 AS nid, 20.177083333333336 AS "E" UNION ALL SELECT 8 AS nid, 28.156 AS "E" UNION ALL SELECT 9 AS nid, 17.99189189189189 AS "E" UNION ALL SELECT 10 AS nid, 10.239062499999998 AS "E") AS "Values"),
# "DT_Output_32" AS
# (SELECT "DT_node_lookup_32"."KEY" AS "KEY", "DT_node_lookup_32".node_id_2 AS node_id_2, "DT_node_data_32".nid AS nid, "DT_node_data_32"."E" AS "E"
# FROM "DT_node_lookup_32" LEFT OUTER JOIN "DT_node_data_32" ON "DT_node_lookup_32".node_id_2 = "DT_node_data_32".nid),
# "RF_Model_32" AS
# (SELECT "DT_Output_32"."KEY" AS "KEY", "DT_Output_32"."E" AS "Estimator"
# FROM "DT_Output_32"),
# "DT_node_lookup_33" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.95) THEN CASE WHEN ("ADS"."Feature_12" <= 4.915) THEN CASE WHEN ("ADS"."Feature_5" <= 7.007) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.0745000000000005) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 19.83) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_33" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.71596244131456 AS "E" UNION ALL SELECT 6 AS nid, 12.411627906976745 AS "E" UNION ALL SELECT 7 AS nid, 30.58709677419355 AS "E" UNION ALL SELECT 8 AS nid, 42.79130434782609 AS "E" UNION ALL SELECT 9 AS nid, 24.56541353383459 AS "E" UNION ALL SELECT 10 AS nid, 36.71 AS "E") AS "Values"),
# "DT_Output_33" AS
# (SELECT "DT_node_lookup_33"."KEY" AS "KEY", "DT_node_lookup_33".node_id_2 AS node_id_2, "DT_node_data_33".nid AS nid, "DT_node_data_33"."E" AS "E"
# FROM "DT_node_lookup_33" LEFT OUTER JOIN "DT_node_data_33" ON "DT_node_lookup_33".node_id_2 = "DT_node_data_33".nid),
# "RF_Model_33" AS
# (SELECT "DT_Output_33"."KEY" AS "KEY", "DT_Output_33"."E" AS "Estimator"
# FROM "DT_Output_33"),
# "DT_node_lookup_34" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.841) THEN CASE WHEN ("ADS"."Feature_0" <= 5.321455) THEN CASE WHEN ("ADS"."Feature_5" <= 6.543) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 9.82) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 3.975) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_34" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 42.947368421052644 AS "E" UNION ALL SELECT 6 AS nid, 32.6515625 AS "E" UNION ALL SELECT 7 AS nid, 20.440449438202243 AS "E" UNION ALL SELECT 8 AS nid, 27.757142857142853 AS "E" UNION ALL SELECT 9 AS nid, 41.23333333333333 AS "E" UNION ALL SELECT 10 AS nid, 12.729807692307684 AS "E") AS "Values"),
# "DT_Output_34" AS
# (SELECT "DT_node_lookup_34"."KEY" AS "KEY", "DT_node_lookup_34".node_id_2 AS node_id_2, "DT_node_data_34".nid AS nid, "DT_node_data_34"."E" AS "E"
# FROM "DT_node_lookup_34" LEFT OUTER JOIN "DT_node_data_34" ON "DT_node_lookup_34".node_id_2 = "DT_node_data_34".nid),
# "RF_Model_34" AS
# (SELECT "DT_Output_34"."KEY" AS "KEY", "DT_Output_34"."E" AS "Estimator"
# FROM "DT_Output_34"),
# "DT_node_lookup_35" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.941) THEN CASE WHEN ("ADS"."Feature_4" <= 0.6695) THEN CASE WHEN ("ADS"."Feature_12" <= 14.035) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 15.145) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_35" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 32.41333333333333 AS "E" UNION ALL SELECT 6 AS nid, 46.11714285714285 AS "E" UNION ALL SELECT 7 AS nid, 23.56681818181818 AS "E" UNION ALL SELECT 8 AS nid, 17.815517241379307 AS "E" UNION ALL SELECT 9 AS nid, 19.916666666666664 AS "E" UNION ALL SELECT 10 AS nid, 12.343939393939396 AS "E") AS "Values"),
# "DT_Output_35" AS
# (SELECT "DT_node_lookup_35"."KEY" AS "KEY", "DT_node_lookup_35".node_id_2 AS node_id_2, "DT_node_data_35".nid AS nid, "DT_node_data_35"."E" AS "E"
# FROM "DT_node_lookup_35" LEFT OUTER JOIN "DT_node_data_35" ON "DT_node_lookup_35".node_id_2 = "DT_node_data_35".nid),
# "RF_Model_35" AS
# (SELECT "DT_Output_35"."KEY" AS "KEY", "DT_Output_35"."E" AS "Estimator"
# FROM "DT_Output_35"),
# "DT_node_lookup_36" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.948) THEN CASE WHEN ("ADS"."Feature_0" <= 5.98991) THEN CASE WHEN ("ADS"."Feature_4" <= 0.5125) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_4" <= 0.6695) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 5.225) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_36" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 42.22500000000001 AS "E" UNION ALL SELECT 6 AS nid, 33.07142857142857 AS "E" UNION ALL SELECT 7 AS nid, 23.506586826347302 AS "E" UNION ALL SELECT 8 AS nid, 19.066853932584266 AS "E" UNION ALL SELECT 9 AS nid, 16.821052631578947 AS "E" UNION ALL SELECT 10 AS nid, 10.279032258064523 AS "E") AS "Values"),
# "DT_Output_36" AS
# (SELECT "DT_node_lookup_36"."KEY" AS "KEY", "DT_node_lookup_36".node_id_2 AS node_id_2, "DT_node_data_36".nid AS nid, "DT_node_data_36"."E" AS "E"
# FROM "DT_node_lookup_36" LEFT OUTER JOIN "DT_node_data_36" ON "DT_node_lookup_36".node_id_2 = "DT_node_data_36".nid),
# "RF_Model_36" AS
# (SELECT "DT_Output_36"."KEY" AS "KEY", "DT_Output_36"."E" AS "Estimator"
# FROM "DT_Output_36"),
# "DT_node_lookup_37" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.791) THEN CASE WHEN ("ADS"."Feature_12" <= 14.35) THEN CASE WHEN ("ADS"."Feature_12" <= 4.77) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 21.49) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.435) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_37" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# ...
# FROM (SELECT 5 AS nid, 33.34878048780489 AS "E" UNION ALL SELECT 6 AS nid, 45.88857142857143 AS "E" UNION ALL SELECT 7 AS nid, 42.63333333333333 AS "E" UNION ALL SELECT 8 AS nid, 22.65114503816794 AS "E" UNION ALL SELECT 9 AS nid, 17.323333333333334 AS "E" UNION ALL SELECT 10 AS nid, 12.143055555555565 AS "E") AS "Values"),
# "DT_Output_492" AS
# (SELECT "DT_node_lookup_492"."KEY" AS "KEY", "DT_node_lookup_492".node_id_2 AS node_id_2, "DT_node_data_492".nid AS nid, "DT_node_data_492"."E" AS "E"
# FROM "DT_node_lookup_492" LEFT OUTER JOIN "DT_node_data_492" ON "DT_node_lookup_492".node_id_2 = "DT_node_data_492".nid),
# "RF_Model_492" AS
# (SELECT "DT_Output_492"."KEY" AS "KEY", "DT_Output_492"."E" AS "Estimator"
# FROM "DT_Output_492"),
# "DT_node_lookup_493" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.63) THEN CASE WHEN ("ADS"."Feature_6" <= 88.7) THEN CASE WHEN ("ADS"."Feature_5" <= 7.435) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_8" <= 14.5) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 5.84803) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_493" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.343925233644853 AS "E" UNION ALL SELECT 6 AS nid, 13.388888888888886 AS "E" UNION ALL SELECT 7 AS nid, 26.532544378698226 AS "E" UNION ALL SELECT 8 AS nid, 44.85 AS "E" UNION ALL SELECT 9 AS nid, 37.48 AS "E" UNION ALL SELECT 10 AS nid, 50.0 AS "E") AS "Values"),
# "DT_Output_493" AS
# (SELECT "DT_node_lookup_493"."KEY" AS "KEY", "DT_node_lookup_493".node_id_2 AS node_id_2, "DT_node_data_493".nid AS nid, "DT_node_data_493"."E" AS "E"
# FROM "DT_node_lookup_493" LEFT OUTER JOIN "DT_node_data_493" ON "DT_node_lookup_493".node_id_2 = "DT_node_data_493".nid),
# "RF_Model_493" AS
# (SELECT "DT_Output_493"."KEY" AS "KEY", "DT_Output_493"."E" AS "Estimator"
# FROM "DT_Output_493"),
# "DT_node_lookup_494" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 5.44) THEN CASE WHEN ("ADS"."Feature_12" <= 3.88) THEN CASE WHEN ("ADS"."Feature_5" <= 7.316) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_7" <= 3.8216) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 14.795) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_494" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 23.3796 AS "E" UNION ALL SELECT 6 AS nid, 15.203468208092485 AS "E" UNION ALL SELECT 7 AS nid, 37.44 AS "E" UNION ALL SELECT 8 AS nid, 47.3 AS "E" UNION ALL SELECT 9 AS nid, 43.21666666666666 AS "E" UNION ALL SELECT 10 AS nid, 32.2125 AS "E") AS "Values"),
# "DT_Output_494" AS
# (SELECT "DT_node_lookup_494"."KEY" AS "KEY", "DT_node_lookup_494".node_id_2 AS node_id_2, "DT_node_data_494".nid AS nid, "DT_node_data_494"."E" AS "E"
# FROM "DT_node_lookup_494" LEFT OUTER JOIN "DT_node_data_494" ON "DT_node_lookup_494".node_id_2 = "DT_node_data_494".nid),
# "RF_Model_494" AS
# (SELECT "DT_Output_494"."KEY" AS "KEY", "DT_Output_494"."E" AS "Estimator"
# FROM "DT_Output_494"),
# "DT_node_lookup_495" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_10" <= 18.75) THEN CASE WHEN ("ADS"."Feature_5" <= 6.727) THEN CASE WHEN ("ADS"."Feature_5" <= 6.047000000000001) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.405999999999999) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_7" <= 1.3387) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_495" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 35.56999999999999 AS "E" UNION ALL SELECT 6 AS nid, 17.999999999999996 AS "E" UNION ALL SELECT 7 AS nid, 19.9 AS "E" UNION ALL SELECT 8 AS nid, 23.761111111111113 AS "E" UNION ALL SELECT 9 AS nid, 32.019230769230774 AS "E" UNION ALL SELECT 10 AS nid, 46.046875 AS "E") AS "Values"),
# "DT_Output_495" AS
# (SELECT "DT_node_lookup_495"."KEY" AS "KEY", "DT_node_lookup_495".node_id_2 AS node_id_2, "DT_node_data_495".nid AS nid, "DT_node_data_495"."E" AS "E"
# FROM "DT_node_lookup_495" LEFT OUTER JOIN "DT_node_data_495" ON "DT_node_lookup_495".node_id_2 = "DT_node_data_495".nid),
# "RF_Model_495" AS
# (SELECT "DT_Output_495"."KEY" AS "KEY", "DT_Output_495"."E" AS "Estimator"
# FROM "DT_Output_495"),
# "DT_node_lookup_496" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.725) THEN CASE WHEN ("ADS"."Feature_12" <= 4.65) THEN CASE WHEN ("ADS"."Feature_5" <= 7.3975) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.0835) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 20.05) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_496" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.151980198019803 AS "E" UNION ALL SELECT 6 AS nid, 12.18125 AS "E" UNION ALL SELECT 7 AS nid, 35.39375 AS "E" UNION ALL SELECT 8 AS nid, 46.0578947368421 AS "E" UNION ALL SELECT 9 AS nid, 24.97419354838709 AS "E" UNION ALL SELECT 10 AS nid, 35.41764705882353 AS "E") AS "Values"),
# "DT_Output_496" AS
# (SELECT "DT_node_lookup_496"."KEY" AS "KEY", "DT_node_lookup_496".node_id_2 AS node_id_2, "DT_node_data_496".nid AS nid, "DT_node_data_496"."E" AS "E"
# FROM "DT_node_lookup_496" LEFT OUTER JOIN "DT_node_data_496" ON "DT_node_lookup_496".node_id_2 = "DT_node_data_496".nid),
# "RF_Model_496" AS
# (SELECT "DT_Output_496"."KEY" AS "KEY", "DT_Output_496"."E" AS "Estimator"
# FROM "DT_Output_496"),
# "DT_node_lookup_497" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_12" <= 9.615) THEN CASE WHEN ("ADS"."Feature_5" <= 6.945) THEN CASE WHEN ("ADS"."Feature_7" <= 1.5492) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_0" <= 6.91188) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_497" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 19.34147465437788 AS "E" UNION ALL SELECT 6 AS nid, 11.941666666666665 AS "E" UNION ALL SELECT 7 AS nid, 50.0 AS "E" UNION ALL SELECT 8 AS nid, 24.98062015503876 AS "E" UNION ALL SELECT 9 AS nid, 34.39782608695652 AS "E" UNION ALL SELECT 10 AS nid, 45.08333333333334 AS "E") AS "Values"),
# "DT_Output_497" AS
# (SELECT "DT_node_lookup_497"."KEY" AS "KEY", "DT_node_lookup_497".node_id_2 AS node_id_2, "DT_node_data_497".nid AS nid, "DT_node_data_497"."E" AS "E"
# FROM "DT_node_lookup_497" LEFT OUTER JOIN "DT_node_data_497" ON "DT_node_lookup_497".node_id_2 = "DT_node_data_497".nid),
# "RF_Model_497" AS
# (SELECT "DT_Output_497"."KEY" AS "KEY", "DT_Output_497"."E" AS "Estimator"
# FROM "DT_Output_497"),
# "DT_node_lookup_498" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.797) THEN CASE WHEN ("ADS"."Feature_12" <= 15.0) THEN CASE WHEN ("ADS"."Feature_12" <= 9.745) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_7" <= 2.0044500000000003) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_12" <= 3.99) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_498" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 44.125925925925934 AS "E" UNION ALL SELECT 6 AS nid, 31.202941176470603 AS "E" UNION ALL SELECT 7 AS nid, 24.660902255639094 AS "E" UNION ALL SELECT 8 AS nid, 20.855737704918035 AS "E" UNION ALL SELECT 9 AS nid, 11.98313253012048 AS "E" UNION ALL SELECT 10 AS nid, 17.42191780821918 AS "E") AS "Values"),
# "DT_Output_498" AS
# (SELECT "DT_node_lookup_498"."KEY" AS "KEY", "DT_node_lookup_498".node_id_2 AS node_id_2, "DT_node_data_498".nid AS nid, "DT_node_data_498"."E" AS "E"
# FROM "DT_node_lookup_498" LEFT OUTER JOIN "DT_node_data_498" ON "DT_node_lookup_498".node_id_2 = "DT_node_data_498".nid),
# "RF_Model_498" AS
# (SELECT "DT_Output_498"."KEY" AS "KEY", "DT_Output_498"."E" AS "Estimator"
# FROM "DT_Output_498"),
# "DT_node_lookup_499" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_5" <= 6.8375) THEN CASE WHEN ("ADS"."Feature_0" <= 5.84803) THEN CASE WHEN ("ADS"."Feature_12" <= 7.835) THEN 7 ELSE 8 END ELSE CASE WHEN ("ADS"."Feature_12" <= 9.82) THEN 9 ELSE 10 END END ELSE CASE WHEN ("ADS"."Feature_5" <= 7.4369999999999985) THEN 5 ELSE 6 END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data_499" AS
# (SELECT "Values".nid AS nid, "Values"."E" AS "E"
# FROM (SELECT 5 AS nid, 31.268627450980397 AS "E" UNION ALL SELECT 6 AS nid, 43.342424242424244 AS "E" UNION ALL SELECT 7 AS nid, 25.813636363636366 AS "E" UNION ALL SELECT 8 AS nid, 19.915789473684207 AS "E" UNION ALL SELECT 9 AS nid, 50.0 AS "E" UNION ALL SELECT 10 AS nid, 12.26744186046512 AS "E") AS "Values"),
# "DT_Output_499" AS
# (SELECT "DT_node_lookup_499"."KEY" AS "KEY", "DT_node_lookup_499".node_id_2 AS node_id_2, "DT_node_data_499".nid AS nid, "DT_node_data_499"."E" AS "E"
# FROM "DT_node_lookup_499" LEFT OUTER JOIN "DT_node_data_499" ON "DT_node_lookup_499".node_id_2 = "DT_node_data_499".nid),
# "RF_Model_499" AS
# (SELECT "DT_Output_499"."KEY" AS "KEY", "DT_Output_499"."E" AS "Estimator"
# FROM "DT_Output_499")
#  SELECT "RF_esu_49"."KEY", "RF_esu_49"."Estimator"
# FROM (SELECT "RF_Model_490"."KEY" AS "KEY", CAST("RF_Model_490"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_490" UNION ALL SELECT "RF_Model_491"."KEY" AS "KEY", CAST("RF_Model_491"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_491" UNION ALL SELECT "RF_Model_492"."KEY" AS "KEY", CAST("RF_Model_492"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_492" UNION ALL SELECT "RF_Model_493"."KEY" AS "KEY", CAST("RF_Model_493"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_493" UNION ALL SELECT "RF_Model_494"."KEY" AS "KEY", CAST("RF_Model_494"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_494" UNION ALL SELECT "RF_Model_495"."KEY" AS "KEY", CAST("RF_Model_495"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_495" UNION ALL SELECT "RF_Model_496"."KEY" AS "KEY", CAST("RF_Model_496"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_496" UNION ALL SELECT "RF_Model_497"."KEY" AS "KEY", CAST("RF_Model_497"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_497" UNION ALL SELECT "RF_Model_498"."KEY" AS "KEY", CAST("RF_Model_498"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_498" UNION ALL SELECT "RF_Model_499"."KEY" AS "KEY", CAST("RF_Model_499"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_Model_499") AS "RF_esu_49"),
# "RF" AS
# (SELECT "RFbig_esu"."KEY" AS "KEY", "RFbig_esu"."Estimator" AS "Estimator"
# FROM (SELECT "RF_0"."KEY" AS "KEY", CAST("RF_0"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_0" UNION ALL SELECT "RF_1"."KEY" AS "KEY", CAST("RF_1"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_1" UNION ALL SELECT "RF_2"."KEY" AS "KEY", CAST("RF_2"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_2" UNION ALL SELECT "RF_3"."KEY" AS "KEY", CAST("RF_3"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_3" UNION ALL SELECT "RF_4"."KEY" AS "KEY", CAST("RF_4"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_4" UNION ALL SELECT "RF_5"."KEY" AS "KEY", CAST("RF_5"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_5" UNION ALL SELECT "RF_6"."KEY" AS "KEY", CAST("RF_6"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_6" UNION ALL SELECT "RF_7"."KEY" AS "KEY", CAST("RF_7"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_7" UNION ALL SELECT "RF_8"."KEY" AS "KEY", CAST("RF_8"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_8" UNION ALL SELECT "RF_9"."KEY" AS "KEY", CAST("RF_9"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_9" UNION ALL SELECT "RF_10"."KEY" AS "KEY", CAST("RF_10"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_10" UNION ALL SELECT "RF_11"."KEY" AS "KEY", CAST("RF_11"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_11" UNION ALL SELECT "RF_12"."KEY" AS "KEY", CAST("RF_12"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_12" UNION ALL SELECT "RF_13"."KEY" AS "KEY", CAST("RF_13"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_13" UNION ALL SELECT "RF_14"."KEY" AS "KEY", CAST("RF_14"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_14" UNION ALL SELECT "RF_15"."KEY" AS "KEY", CAST("RF_15"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_15" UNION ALL SELECT "RF_16"."KEY" AS "KEY", CAST("RF_16"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_16" UNION ALL SELECT "RF_17"."KEY" AS "KEY", CAST("RF_17"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_17" UNION ALL SELECT "RF_18"."KEY" AS "KEY", CAST("RF_18"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_18" UNION ALL SELECT "RF_19"."KEY" AS "KEY", CAST("RF_19"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_19" UNION ALL SELECT "RF_20"."KEY" AS "KEY", CAST("RF_20"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_20" UNION ALL SELECT "RF_21"."KEY" AS "KEY", CAST("RF_21"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_21" UNION ALL SELECT "RF_22"."KEY" AS "KEY", CAST("RF_22"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_22" UNION ALL SELECT "RF_23"."KEY" AS "KEY", CAST("RF_23"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_23" UNION ALL SELECT "RF_24"."KEY" AS "KEY", CAST("RF_24"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_24" UNION ALL SELECT "RF_25"."KEY" AS "KEY", CAST("RF_25"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_25" UNION ALL SELECT "RF_26"."KEY" AS "KEY", CAST("RF_26"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_26" UNION ALL SELECT "RF_27"."KEY" AS "KEY", CAST("RF_27"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_27" UNION ALL SELECT "RF_28"."KEY" AS "KEY", CAST("RF_28"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_28" UNION ALL SELECT "RF_29"."KEY" AS "KEY", CAST("RF_29"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_29" UNION ALL SELECT "RF_30"."KEY" AS "KEY", CAST("RF_30"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_30" UNION ALL SELECT "RF_31"."KEY" AS "KEY", CAST("RF_31"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_31" UNION ALL SELECT "RF_32"."KEY" AS "KEY", CAST("RF_32"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_32" UNION ALL SELECT "RF_33"."KEY" AS "KEY", CAST("RF_33"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_33" UNION ALL SELECT "RF_34"."KEY" AS "KEY", CAST("RF_34"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_34" UNION ALL SELECT "RF_35"."KEY" AS "KEY", CAST("RF_35"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_35" UNION ALL SELECT "RF_36"."KEY" AS "KEY", CAST("RF_36"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_36" UNION ALL SELECT "RF_37"."KEY" AS "KEY", CAST("RF_37"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_37" UNION ALL SELECT "RF_38"."KEY" AS "KEY", CAST("RF_38"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_38" UNION ALL SELECT "RF_39"."KEY" AS "KEY", CAST("RF_39"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_39" UNION ALL SELECT "RF_40"."KEY" AS "KEY", CAST("RF_40"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_40" UNION ALL SELECT "RF_41"."KEY" AS "KEY", CAST("RF_41"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_41" UNION ALL SELECT "RF_42"."KEY" AS "KEY", CAST("RF_42"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_42" UNION ALL SELECT "RF_43"."KEY" AS "KEY", CAST("RF_43"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_43" UNION ALL SELECT "RF_44"."KEY" AS "KEY", CAST("RF_44"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_44" UNION ALL SELECT "RF_45"."KEY" AS "KEY", CAST("RF_45"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_45" UNION ALL SELECT "RF_46"."KEY" AS "KEY", CAST("RF_46"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_46" UNION ALL SELECT "RF_47"."KEY" AS "KEY", CAST("RF_47"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_47" UNION ALL SELECT "RF_48"."KEY" AS "KEY", CAST("RF_48"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_48" UNION ALL SELECT "RF_49"."KEY" AS "KEY", CAST("RF_49"."Estimator" AS FLOAT) AS "Estimator"
# FROM "RF_49") AS "RFbig_esu"),
# "RF_avg" AS
# (SELECT "T"."KEY" AS "KEY", CAST("T"."Estimator" AS FLOAT) AS "Estimator"
# FROM (SELECT "RF"."KEY" AS "KEY", avg(CAST("RF"."Estimator" AS FLOAT)) AS "Estimator"
# FROM "RF" GROUP BY "RF"."KEY") AS "T")
#  SELECT "RF_avg"."KEY" AS "KEY", "RF_avg"."Estimator" AS "Estimator"
# FROM "RF_avg"

# %% [markdown]
# # Execute the SQL Code

# %%
library(RODBC)
conn = odbcConnect("pgsql", uid="db", pwd="db", case="nochange")
odbcSetAutoCommit(conn , autoCommit = TRUE)
# Out:
# [1] 0

# %%
df_sql = dataset
names(df_sql) = sprintf("Feature_%d",0:(ncol(df_sql)-1))
df_sql$KEY = seq.int(nrow(dataset))

sqlDrop(conn , "INPUT_DATA" , errors = FALSE)
sqlSave(conn, df_sql, tablename = "INPUT_DATA", verbose = FALSE)

# df_sql

# %%
colnames(df_sql)
# odbcGetInfo(conn)
# sqlTables(conn)
# Out:
#  [1] "Feature_0"  "Feature_1"  "Feature_2"  "Feature_3"  "Feature_4"
#  [6] "Feature_5"  "Feature_6"  "Feature_7"  "Feature_8"  "Feature_9"
# [11] "Feature_10" "Feature_11" "Feature_12" "KEY"

# %%
df_sql_out = sqlQuery(conn, lModelSQL)
head(df_sql_out[order(df_sql_out$KEY),])
# Out:
#     KEY Estimator
# 374 1   26.44055
# 84  2   22.80415
# 168 3   34.34079
# 56  4   34.08041
# 320 5   32.05006
# 64  6   25.46612

# %%
# df_sql_out

# %% [markdown]
# # R RandomForest Output

# %%
estimator  =  predict(model, dataset, type = "raw")
df_r_out = data.frame(estimator)
names(df_r_out) = c("Estimator")

df_r_out$KEY = seq.int(nrow(dataset))
head(df_r_out)
# Out:
#   Estimator KEY
# 1 26.44055  1
# 2 22.80415  2
# 3 34.34079  3
# 4 34.08041  4
# 5 32.05006  5
# 6 25.46612  6

# %% [markdown]
# # Compare R and SQL output

# %%
df_merge = merge(x = df_r_out, y = df_sql_out, by = "KEY", all = TRUE, , suffixes = c("_1","_2"))
head(df_merge)
# Out:
#   KEY Estimator_1 Estimator_2
# 1 1   26.44055    26.44055
# 2 2   22.80415    22.80415
# 3 3   34.34079    34.34079
# 4 4   34.08041    34.08041
# 5 5   32.05006    32.05006
# 6 6   25.46612    25.46612

# %%
df_merge$Error = df_merge$Estimator_1 - df_merge$Estimator_2
df_merge$AbsError = abs(df_merge$Error)
head(df_merge)
# Out:
#   KEY Estimator_1 Estimator_2 Error         AbsError
# 1 1   26.44055    26.44055     0.000000e+00 0.000000e+00
# 2 2   22.80415    22.80415    -3.552714e-15 3.552714e-15
# 3 3   34.34079    34.34079     0.000000e+00 0.000000e+00
# 4 4   34.08041    34.08041     0.000000e+00 0.000000e+00
# 5 5   32.05006    32.05006     0.000000e+00 0.000000e+00
# 6 6   25.46612    25.46612    -3.552714e-15 3.552714e-15

# %%
df_merge_largest_errors = df_merge[df_merge$AbsError > 0.0001,]
df_merge_largest_errors
# Out:
#     KEY Estimator_1 Estimator_2 Error        AbsError
# 23   23 17.92935    17.91996     0.009391431 0.009391431
# 39   39 21.31817    21.34178    -0.023617533 0.023617533
# 176 176 25.70728    25.68060     0.026687064 0.026687064
# 434 434 16.52184    16.50997     0.011866726 0.011866726

# %%
nrow(df_merge_largest_errors)
stopifnot(nrow(df_merge_largest_errors) == 0)
# Out:
# [1] 4
# Error in eval(expr, envir, enclos): nrow(df_merge_largest_errors) == 0 is not TRUE
# Traceback:
#
# 1. stopifnot(nrow(df_merge_largest_errors) == 0)

# %%
summary(df_sql_out)
# Out:
#       KEY          Estimator
#  Min.   :  1.0   Min.   :13.31
#  1st Qu.:127.2   1st Qu.:17.93
#  Median :253.5   Median :21.01
#  Mean   :253.5   Mean   :22.49
#  3rd Qu.:379.8   3rd Qu.:24.45
#  Max.   :506.0   Max.   :43.96

# %%
summary(df_r_out)
# Out:
#    Estimator          KEY
#  Min.   :13.31   Min.   :  1.0
#  1st Qu.:17.93   1st Qu.:127.2
#  Median :21.01   Median :253.5
#  Mean   :22.49   Mean   :253.5
#  3rd Qu.:24.45   3rd Qu.:379.8
#  Max.   :43.96   Max.   :506.0

# %%
summary(df_merge)
# Out:
#       KEY         Estimator_1     Estimator_2        Error
#  Min.   :  1.0   Min.   :13.31   Min.   :13.31   Min.   :-2.362e-02
#  1st Qu.:127.2   1st Qu.:17.93   1st Qu.:17.93   1st Qu.: 0.000e+00
#  Median :253.5   Median :21.01   Median :21.01   Median : 0.000e+00
#  Mean   :253.5   Mean   :22.49   Mean   :22.49   Mean   : 4.808e-05
#  3rd Qu.:379.8   3rd Qu.:24.45   3rd Qu.:24.45   3rd Qu.: 0.000e+00
#  Max.   :506.0   Max.   :43.96   Max.   :43.96   Max.   : 2.669e-02
#     AbsError
#  Min.   :0.0000000
#  1st Qu.:0.0000000
#  Median :0.0000000
#  Mean   :0.0001414
#  3rd Qu.:0.0000000
#  Max.   :0.0266871
